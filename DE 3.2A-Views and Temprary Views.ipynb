# %%
FilePath='/FileStore/tables/hw_200.csv'

# %%
dbutils.fs.rm('/FileStore/tables/hw_200.csv')
# Out:
# Out[53]: True

# %%
# %sql
DROP TABLE IF EXISTS spark_catalog.default.HW_200;
CREATE TABLE HW_200
USING CSV OPTIONS(
  Path='/FileStore/tables/hw_200.csv',
  header="true",
  mode="FAILFAST"
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from HW_200
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SHOW tables;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>hw_200</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM hw_200
WHERE Height <> 65.78
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE VIEW V_HW_1 AS
  select * 
  from hw_200
     where Height>50
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW Tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>hw_200</td><td>false</td></tr><tr><td>default</td><td>v_hw_1</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# Creating a temporary view

# %%
# %sql
CREATE TEMPORARY VIEW V_HW_2 AS
SELECT * from hw_200 where height>70
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-3366380397222697>:7
#       5     display(df)
#       6     return df
# ----> 7   _sqldf = ____databricks_percent_sql()
#       8 finally:
#       9   del ____databricks_percent_sql
#
# File <command-3366380397222697>:4, in ____databricks_percent_sql()
#       2 def ____databricks_percent_sql():
#       3   import base64
# ----> 4   df = spark.sql(base64.standard_b64decode("Q1JFQVRFIFRFTVBPUkFSWSBWSUVXIFZfSFdfMiBBUw==").decode())
#       5   display(df)
#       6   return df
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
# ...

# %%
# %sql
select * from V_hw_2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>hw_200</td><td>false</td></tr><tr><td>default</td><td>v_hw_1</td><td>false</td></tr><tr><td></td><td>v_hw_2</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# Creating a global temp view

# %%
# %sql
CREATE GLOBAL TEMPORARY VIEW V_HW_3 AS
SELECT * from hw_200 where height>90
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>hw_200</td><td>false</td></tr><tr><td>default</td><td>v_hw_1</td><td>false</td></tr><tr><td></td><td>v_hw_2</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
SHOW TABLES IN global_temp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>global_temp</td><td>v_hw_2</td><td>true</td></tr><tr><td>global_temp</td><td>v_hw_3</td><td>true</td></tr><tr><td></td><td>v_hw_2</td><td>true</td></tr></tbody></table></div>
